# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go
from mpl_toolkits.basemap import Basemap

sns.set()
# %matplotlib inline

# %%
DATA = "gun-violence-data_01-2013_03-2018.csv"
POPULATION_DATA = "population.csv"

# %% [markdown]
# https://plot.ly/python/choropleth-maps/

# %% [markdown]
# # Вспомогательный код

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}
states_inv = dict(((v, k) for k, v in states.items()))

# %%
def show_USA(data, title, bartitle, showcountries=False):
    scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
                [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

    data = [ dict(
            type='choropleth',
            colorscale = scl,
            autocolorscale = False,
            locations = [states_inv[x] for x in data.index],
            z = data.values.astype(float),
            locationmode = 'USA-states',
            text = list(data.index),
            marker = dict(
                line = dict (
                    color = 'rgb(255,255,255)',
                    width = 2
                ) ),
            colorbar = dict(
                title = bartitle)
            ) ]

    layout = dict(
            title = title,
            geo = dict(
                scope='usa',
                projection=dict( type='albers usa' ),
                showlakes = True,
                showcountries = showcountries,
                lakecolor = 'rgb(255, 255, 255)')
                 )

    fig = dict( data=data, layout=layout )
    return fig

# %% [markdown]
# # Загрузка данных

# %%
data = pd.read_csv(DATA, index_col=0)

# %%
population_data = pd.read_csv(POPULATION_DATA, index_col='State')['2018 Population']

# %%
incidents_by_state = data.groupby('state').date.count()

# %% [markdown]
# # Предварительный просмотр

# %%
data.head()
# Out:
#                    date           state city_or_county  \
# incident_id
# 461105       2013-01-01    Pennsylvania     Mckeesport
# 460726       2013-01-01      California      Hawthorne
# 478855       2013-01-01            Ohio         Lorain
# 478925       2013-01-05        Colorado         Aurora
# 478959       2013-01-07  North Carolina     Greensboro
#
#                                                address  n_killed  n_injured  \
# incident_id
# 461105       1506 Versailles Avenue and Coursin Street         0          4
# 460726                    13500 block of Cerise Avenue         1          3
# 478855                           1776 East 28th Street         1          3
# 478925                16000 block of East Ithaca Place         4          0
# 478959                       307 Mourning Dove Terrace         2          2
#
#                                                   incident_url  \
# incident_id
# 461105       http://www.gunviolencearchive.org/incident/461105
# 460726       http://www.gunviolencearchive.org/incident/460726
# 478855       http://www.gunviolencearchive.org/incident/478855
# 478925       http://www.gunviolencearchive.org/incident/478925
# 478959       http://www.gunviolencearchive.org/incident/478959
#
#                                                     source_url  \
# incident_id
# 461105       http://www.post-gazette.com/local/south/2013/0...
# 460726       http://www.dailybulletin.com/article/zz/201301...
# 478855       http://chronicle.northcoastnow.com/2013/02/14/...
# 478925       http://www.dailydemocrat.com/20130106/aurora-s...
# 478959       http://www.journalnow.com/news/local/article_d...
#
#              incident_url_fields_missing  congressional_district  \
# incident_id
# 461105                             False                    14.0
# 460726                             False                    43.0
# 478855                             False                     9.0
# 478925                             False                     6.0
# 478959                             False                     6.0
#
#                      ...                             participant_age  \
# incident_id          ...
# 461105               ...                                       0::20
# 460726               ...                                       0::20
# 478855               ...           0::25||1::31||2::33||3::34||4::33
# 478925               ...                  0::29||1::33||2::56||3::33
# 478959               ...                  0::18||1::46||2::14||3::47
#
#                                          participant_age_group  \
# incident_id
# 461105       0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 460726       0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 478855       0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 478925       0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 478959       0::Adult 18+||1::Adult 18+||2::Teen 12-17||3::...
#
#                                       participant_gender  \
# incident_id
# 461105              0::Male||1::Male||3::Male||4::Female
# 460726                                           0::Male
# 478855       0::Male||1::Male||2::Male||3::Male||4::Male
# 478925              0::Female||1::Male||2::Male||3::Male
# 478959            0::Female||1::Male||2::Male||3::Female
#
#                                               participant_name  \
# incident_id
# 461105                                          0::Julian Sims
# 460726                                       0::Bernard Gillis
# 478855       0::Damien Bell||1::Desmen Noble||2::Herman Sea...
# 478925       0::Stacie Philbrook||1::Christopher Ratliffe||...
# 478959       0::Danielle Imani Jameison||1::Maurice Eugene ...
#
#             participant_relationship  \
# incident_id
# 461105                           NaN
# 460726                           NaN
# 478855                           NaN
# 478925                           NaN
# 478959                     3::Family
#
#                                             participant_status  \
# incident_id
# 461105       0::Arrested||1::Injured||2::Injured||3::Injure...
# 460726           0::Killed||1::Injured||2::Injured||3::Injured
# 478855       0::Injured, Unharmed, Arrested||1::Unharmed, A...
# 478925              0::Killed||1::Killed||2::Killed||3::Killed
# 478959            0::Injured||1::Injured||2::Killed||3::Killed
#
#                                               participant_type  \
# incident_id
# 461105       0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 460726       0::Victim||1::Victim||2::Victim||3::Victim||4:...
# 478855       0::Subject-Suspect||1::Subject-Suspect||2::Vic...
# 478925       0::Victim||1::Victim||2::Victim||3::Subject-Su...
# 478959       0::Victim||1::Victim||2::Victim||3::Subject-Su...
#
#                                                        sources  \
# incident_id
# 461105       http://pittsburgh.cbslocal.com/2013/01/01/4-pe...
# 460726       http://losangeles.cbslocal.com/2013/01/01/man-...
# 478855       http://www.morningjournal.com/general-news/201...
# 478925       http://denver.cbslocal.com/2013/01/06/officer-...
# 478959       http://myfox8.com/2013/01/08/update-mother-sho...
#
#             state_house_district state_senate_district
# incident_id
# 461105                       NaN                   NaN
# 460726                      62.0                  35.0
# 478855                      56.0                  13.0
# 478925                      40.0                  28.0
# 478959                      62.0                  27.0
#
# [5 rows x 28 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239677 entries, 461105 to 1081940
# Data columns (total 28 columns):
# date                           239677 non-null object
# state                          239677 non-null object
# city_or_county                 239677 non-null object
# address                        223180 non-null object
# n_killed                       239677 non-null int64
# n_injured                      239677 non-null int64
# incident_url                   239677 non-null object
# source_url                     239209 non-null object
# incident_url_fields_missing    239677 non-null bool
# congressional_district         227733 non-null float64
# gun_stolen                     140179 non-null object
# gun_type                       140226 non-null object
# incident_characteristics       239351 non-null object
# latitude                       231754 non-null float64
# location_description           42089 non-null object
# longitude                      231754 non-null float64
# n_guns_involved                140226 non-null float64
# notes                          158660 non-null object
# participant_age                147379 non-null object
# participant_age_group          197558 non-null object
# participant_gender             203315 non-null object
# participant_name               117424 non-null object
# participant_relationship       15774 non-null object
# participant_status             212051 non-null object
# participant_type               214814 non-null object
# sources                        239068 non-null object
# state_house_district           200905 non-null float64
# state_senate_district          207342 non-null float64
# dtypes: bool(1), float64(6), int64(2), object(19)
# memory usage: 34.1+ MB

# %%
data.describe()
# Out:
#             n_killed      n_injured  congressional_district       latitude  \
# count  239677.000000  239677.000000           227733.000000  231754.000000
# mean        0.252290       0.494007                8.001265      37.546598
# std         0.521779       0.729952                8.480835       5.130763
# min         0.000000       0.000000                0.000000      19.111400
# 25%         0.000000       0.000000                2.000000      33.903400
# 50%         0.000000       0.000000                5.000000      38.570600
# 75%         0.000000       1.000000               10.000000      41.437375
# max        50.000000      53.000000               53.000000      71.336800
#
#            longitude  n_guns_involved  state_house_district  \
# count  231754.000000    140226.000000         200905.000000
# mean      -89.338348         1.372442             55.447132
# std        14.359546         4.678202             42.048117
# min      -171.429000         1.000000              1.000000
# 25%       -94.158725         1.000000             21.000000
# 50%       -86.249600         1.000000             47.000000
# 75%       -80.048625         1.000000             84.000000
# max        97.433100       400.000000            901.000000
#
#        state_senate_district
# count           207342.00000
# mean                20.47711
# std                 14.20456
# min                  1.00000
# 25%                  9.00000
# 50%                 19.00000
# 75%                 30.00000
# max                 94.00000

# %%
data.participant_age.head()
# Out:
# incident_id
# 461105                                0::20
# 460726                                0::20
# 478855    0::25||1::31||2::33||3::34||4::33
# 478925           0::29||1::33||2::56||3::33
# 478959           0::18||1::46||2::14||3::47
# Name: participant_age, dtype: object

# %%
ages =  [x.split('||') if x is not np.nan else np.nan for x in data.participant_age.values]

# %%
ages
# Out:
# [['0::20'],
#  ['0::20'],
#  ['0::25', '1::31', '2::33', '3::34', '4::33'],
#  ['0::29', '1::33', '2::56', '3::33'],
#  ['0::18', '1::46', '2::14', '3::47'],
#  ['0::23', '1::23', '2::33', '3::55'],
#  ['0::51', '1::40', '2::9', '3::5', '4::2', '5::15'],
#  nan,
#  nan,
#  ['0::15'],
#  ['0::19'],
#  ['0::28'],
#  ['3::78', '4::48'],
#  nan,
#  ['0::34', '1::28', '2::23', '3::29', '4::29'],
#  ['5::24'],
#  ['0::20', '4::25', '5::18', '6::19'],
#  ['0::18', '1::41', '2::28', '3::28'],
#  ['0::18', '1::22', '2::21', '3::29', '4::19', '5::22', '6::23'],
#  ['0::22'],
#  ['1::39', '4::68'],
#  ['0::35', '1::34', '2::26', '4::25'],
#  ['0::20', '4::69', '5::27', '6::20'],
#  ['0::18', '1::18', '2::18', '3::19', '4::41'],
#  nan,
#  ['0::22', '1::26', '2::29', '3::37'],
#  ['8::29'],
#  ['0::18', '1::18', '2::18', '3::19', '4::15', '5::17'],
#  ['0::50', '1::42', '4::24', '5::25'],
#  ['0::23', '1::34', '2::17', '3::25'],
#  ['3::18', '4::17', '5::15'],
#  ['0::19', '1::19', '2::19', '3::25'],
#  ['0::33', '1::28', '2::29', '3::21', '4::25'],
#  ['0::20', '1::20', '2::17', '3::20', '4::15'],
#  ['0::19', '1::19', '2::17', '15::21'],
#  ['0::16', '1::13', '4::23', '5::20', '6::20', '7::18'],
#  ['0::68', '1::57', '2::66', '3::67', '4::62', '5::51', '6::2', '7::64'],
#  nan,
#  nan,
#  ['0::21', '1::36'],
#  nan,
#  ['0::19', '1::21', '2::23', '3::20', '4::26', '5::21', '6::36'],
#  ['0::23', '4::21', '5::20'],
#  ['0::62', '1::24', '3::40', '4::29'],
#  ['0::18', '1::19', '2::16', '3::16', '4::21', '5::19', '6::20'],
#  ['0::23', '1::21', '2::25', '4::29'],
#  ['4::15', '5::17'],
#  ['0::22', '1::23', '2::23', '3::22', '4::43'],
#  ['0::23'],
#  ['0::21', '1::18', '2::22', '3::33'],
#  nan,
#  ['0::18', '1::16', '2::16', '3::17', '4::18', '5::21', '6::22'],
#  ['0::22', '2::20', '3::24', '4::23', '5::22'],
#  ['0::19', '1::19', '2::23', '3::24', '4::22'],
#  ['0::62', '1::25', '2::46', '3::23', '4::28'],
#  ['0::19', '1::30', '2::32', '3::34'],
#  ['0::2',
#   '1::1',
#   '2::3',
#   '3::67',
#   '4::63',
#   '5::19',
#   '6::18',
#   '7::21',
#   '8::20'],
#  ['0::64', '1::22', '2::29', '3::5', '4::1'],
#  ['0::17', '1::22', '2::23', '3::26'],
#  ['0::36', '5::19'],
#  nan,
#  ['0::17', '1::16', '2::18', '3::40'],
#  ['0::31', '1::31', '2::32', '3::22', '5::31', '6::27'],
#  ['0::22', '1::25'],
#  ['0::10', '1::22', '2::25', '3::46', '4::48'],
#  ['4::29'],
#  nan,
#  nan,
#  nan,
#  ['0::41', '1::41', '2::53', '3::39', '4::55'],
#  ['0::15', '1::16', '2::17', '3::20'],
#  nan,
#  ['4::47'],
#  ['17::10', '18::10', '19::19', '20::23'],
#  nan,
#  ['1::22'],
#  ['0::60', '1::58', '2::15', '3::24', '4::32', '5::24'],
#  ['0::41', '1::21', '2::26'],
#  ['0::14', '1::15', '2::21'],
#  ['4::22'],
#  ['0::18', '1::14', '2::28'],
#  ['0::18', '1::22', '2::27', '3::30'],
#  ['0::14', '1::17', '2::18', '3::19'],
#  ['1::72', '2::45', '4::37'],
#  ['0::20', '1::17', '4::21'],
#  ['0::20'],
#  ['0::16', '1::14', '2::16', '3::17', '4::18', '5::15', '6::17'],
#  ['0::17', '1::18', '2::19', '3::20'],
#  ['0::19', '1::18', '2::17', '3::14'],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::55', '1::25', '2::68', '3::26', '4::68', '5::50', '6::23'],
#  nan,
#  ['0::13', '1::14', '2::15', '3::17', '4::22', '5::34', '6::21'],
#  ['0::18', '1::15', '2::18', '3::21', '4::20'],
#  ['0::20', '1::20', '2::43', '3::49', '4::21', '5::18'],
#  ['0::12',
#   '1::44',
#   '2::23',
#   '3::33',
#   '4::21',
#   '5::20',
#   '6::23',
#   '7::19',
#   '8::17'],
#  ['0::34', '1::14', '2::14', '3::15', '4::39'],
#  ['0::43', '1::24', '2::27', '3::28'],
#  ['0::40', '1::40', '2::35', '3::35'],
#  ['0::21', '1::30', '2::28', '3::17', '4::20'],
#  ['0::16', '1::17', '6::25', '7::20', '8::20', '9::24'],
#  ['0::70', '1::69', '2::50', '3::64', '4::23'],
#  ['0::18'],
#  ['0::39', '1::26'],
#  ['0::19', '1::21', '2::30'],
#  ['0::19', '1::15', '2::17', '3::18', '4::19'],
#  ['0::23', '1::17'],
#  ['0::18', '1::20', '2::18', '3::18'],
#  ['0::25'],
#  ['0::27'],
#  ['0::19', '1::20', '2::20', '3::19', '4::18'],
#  ['0::28', '1::29', '2::20', '3::28', '4::21', '5::17'],
#  ['0::24', '1::23', '2::24', '3::30', '4::33', '5::22'],
#  ['0::41', '1::39', '2::36', '4::43', '5::32'],
#  nan,
#  nan,
#  ['0::22'],
#  ['0::39', '1::22', '2::10', '3::0', '4::22'],
#  ['0::21', '1::19'],
#  ['0::14', '1::35', '2::54', '3::37'],
#  ['0::35', '1::6', '2::12', '3::22', '4::22', '5::28', '6::23', '7::35'],
#  ['0::18', '1::13', '2::14', '3::15', '4::21'],
#  ['4::22'],
#  ['0::40', '1::49', '2::20', '3::16', '4::17', '5::43'],
#  nan,
#  ['0::19', '1::40', '2::18', '3::23', '4::18'],
#  ['0::23', '1::54', '2::35', '3::23'],
#  ['4::29'],
#  ['0::17', '1::33', '2::38'],
#  ['0::21', '1::22', '4::23'],
#  ['0::24', '1::22', '2::23', '3::23'],
#  ['0::40', '1::43', '3::22'],
#  ['0::62', '1::43', '2::29', '3::24', '4::33'],
#  nan,
#  ['0::42', '1::22', '2::41', '3::33'],
#  ['0::17', '1::17', '2::18', '3::17', '4::17'],
#  ['5::18'],
#  ['0::27', '1::26', '2::33', '5::28', '6::32'],
#  ['0::8', '1::4', '2::7', '3::64', '4::22', '5::27'],
#  nan,
#  ['0::17', '1::19', '2::19', '3::18'],
#  ['0::45', '1::37', '2::22', '3::52', '4::62', '5::23'],
#  ['0::25'],
#  ['0::21', '1::20', '2::17', '3::16'],
#  nan,
#  ['0::70', '1::47', '2::29', '3::26', '4::27'],
#  ['0::79', '1::69', '2::33', '3::64', '4::51', '5::17', '6::42'],
#  nan,
#  ['0::14', '1::16', '2::17', '3::19'],
#  ['0::29', '1::24', '2::23', '3::18', '4::20'],
#  ['4::28'],
#  ['0::36', '1::37', '2::34', '3::39', '4::45'],
#  ['0::8', '1::16'],
#  ['0::22', '1::25', '2::28', '7::21'],
#  ['0::19'],
#  ['1::30'],
#  ['0::62', '1::53', '2::64', '6::59'],
#  ['0::18', '1::20', '2::17', '3::18'],
#  ['0::47',
#   '1::28',
#   '2::11',
#   '3::13',
#   '4::43',
#   '5::17',
#   '6::14',
#   '7::17',
#   '8::44'],
#  ['0::26', '1::27', '2::22', '3::29'],
#  ['0::16', '1::17', '2::20', '3::20'],
#  nan,
#  ['0::31'],
#  nan,
#  ['0::53', '1::34', '2::16', '3::0', '4::40'],
#  ['1::25'],
#  ['4::20'],
#  nan,
#  ['0::19', '1::17', '2::22', '3::18'],
#  ['1::15', '2::17', '4::19', '5::17', '6::23', '7::25', '8::21', '9::24'],
#  ['0::24', '1::21', '2::23', '3::20'],
#  ['5::20'],
#  ['0::22', '1::21', '4::35'],
#  ['0::26', '1::39'],
#  ['0::21', '5::21', '6::19'],
#  ['0::18', '1::20'],
#  ['0::28', '1::80', '2::66', '3::44', '4::72'],
#  ['0::8', '1::12', '2::17', '3::44'],
#  ['0::11', '1::18', '2::19', '3::22', '4::22'],
#  ['0::36', '1::21', '2::38', '3::49', '4::21'],
#  ['0::32', '1::18'],
#  ['0::26', '1::15', '2::15', '3::19', '4::19', '5::23', '6::19', '7::20'],
#  nan,
#  ['0::22', '1::17', '2::17', '3::16', '4::26', '5::25'],
#  ['0::32'],
#  ['4::35'],
#  nan,
#  ['0::34', '1::23', '2::19', '3::12', '4::33'],
#  ['0::31', '1::20', '2::28', '3::29', '4::22', '5::23'],
#  ['0::59',
#   '1::53',
#   '2::51',
#   '3::53',
#   '4::62',
#   '5::73',
#   '6::51',
#   '7::50',
#   '8::61',
#   '9::46',
#   '10::58',
#   '11::52',
#   '15::34'],
#  ['0::26', '1::22', '2::23', '3::30', '4::34'],
#  ['0::17', '1::14', '2::15', '3::15', '4::17', '5::16'],
#  ['3::11'],
#  nan,
#  ['0::22'],
#  ['0::3',
#   '1::17',
#   '2::15',
#   '3::27',
#   '4::24',
#   '5::21',
#   '6::41',
#   '7::33',
#   '8::31',
#   '9::23',
#   '10::37',
#   '11::25',
#   '12::33',
#   '13::20',
#   '14::21',
#   '15::22',
#   '16::28',
#   '17::22',
#   '18::20',
#   '19::22'],
#  ['0::26', '1::24'],
#  ['0::33', '1::10', '2::8', '3::4', '4::33'],
#  nan,
#  ['0::21', '1::36', '2::33', '3::22'],
#  ['0::20', '1::20', '2::20', '5::20', '6::20'],
#  ['0::25', '1::25', '2::26', '3::26', '4::27', '5::28', '6::35'],
#  ['0::21', '1::36', '2::22', '3::23', '4::19', '5::23', '6::31'],
#  ['4::20'],
#  ['4::26'],
#  ['0::22', '1::21', '2::18', '3::16'],
#  ['0::19', '1::16', '2::16', '3::2'],
#  ['0::21'],
#  ['0::18'],
#  nan,
#  nan,
#  ['0::23', '1::23', '2::21', '3::18', '4::18', '5::18'],
#  ['0::47', '1::37'],
#  ['0::18', '1::21', '2::24', '3::32'],
#  ['5::21', '6::19'],
#  ['0::34', '1::24'],
#  ['8::15'],
#  nan,
#  ['0::67', '2::40', '3::49'],
#  ['0::21', '1::27'],
#  ['0::26', '1::19', '2::29', '3::24', '4::34', '5::25', '6::29'],
#  nan,
#  ['0::66', '1::42', '2::36', '3::17', '4::56'],
#  nan,
#  ['4::32'],
#  ['0::31', '1::22', '2::38', '3::22', '4::28'],
#  ['0::19'],
#  ['0::26', '1::49', '2::51', '3::11', '4::9', '5::27'],
#  ['0::47'],
#  ['4::36'],
#  ['0::39', '1::29', '2::54', '3::36'],
#  ['0::60', '4::51'],
#  ['0::25', '1::27', '2::21', '3::22'],
#  ['0::61', '1::29', '2::40'],
#  ['0::17', '1::16', '2::16', '18::21', '19::18'],
#  ['0::45', '1::26', '2::27', '3::24', '4::45'],
#  ['0::19',
#   '1::18',
#   '2::21',
#   '3::22',
#   '4::15',
#   '5::18',
#   '6::18',
#   '7::18',
#   '8::21'],
#  ['0::28', '1::27', '2::35', '3::22', '4::29'],
#  ['0::17'],
#  ['0::17', '1::17', '2::21', '5::25'],
#  ['0::24', '1::24', '2::26', '3::27'],
#  ['1::24'],
#  ['0::30', '1::27'],
#  ['0::34', '1::35', '2::46', '3::54', '4::55'],
#  ['0::23', '1::27', '2::28', '3::29', '4::29', '5::29', '6::31'],
#  ['0::32', '1::19', '2::22', '3::30'],
#  ['0::23', '1::23', '2::25', '3::25'],
#  ['0::16', '1::18', '2::16', '3::17'],
#  ['0::15'],
#  nan,
#  nan,
#  ['0::18', '1::22', '2::23'],
#  ['0::36', '1::51'],
#  ['0::43', '1::56', '2::45', '3::34'],
#  ['0::21', '1::22', '2::24', '3::33'],
#  ['0::36', '1::21'],
#  ['0::15', '1::17', '2::17', '3::19'],
#  ['0::17'],
#  nan,
#  ['0::24'],
#  nan,
#  ['0::21', '4::22'],
#  ['0::19', '4::19'],
#  ['0::25'],
#  ['0::34', '1::32', '2::27', '3::27', '4::34'],
#  ['0::61', '1::61', '2::40', '3::67', '4::51', '5::38'],
#  ['0::22', '1::23', '8::22'],
#  ['0::21',
#   '1::22',
#   '2::20',
#   '3::20',
#   '4::23',
#   '5::20',
#   '6::24',
#   '8::25',
#   '9::25'],
#  ['0::24', '1::36'],
#  ['0::85', '1::30'],
#  ['0::18', '1::14', '2::42', '3::38', '4::22', '5::30'],
#  ['0::16', '1::18', '2::18', '3::19', '4::16', '5::17'],
#  ['0::13'],
#  nan,
#  nan,
#  ['0::22', '1::26'],
#  ['0::34'],
#  ['0::6', '1::12'],
#  ['0::27', '1::25'],
#  ['0::20'],
#  nan,
#  ['0::24', '1::35'],
#  ['0::31', '1::25'],
#  ['0::18'],
#  ['0::19', '1::19'],
#  ['0::52'],
#  nan,
#  ['0::28'],
#  ['0::47'],
#  nan,
#  ['0::26', '1::19'],
#  ['0::21', '1::24'],
#  nan,
#  nan,
#  nan,
#  ['0::60'],
#  ['0::31'],
#  nan,
#  ['0::23'],
#  ['0::46'],
#  ['0::19'],
#  ['0::24', '1::25', '2::23'],
#  ['0::35'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::31', '1::32'],
#  nan,
#  ['0::31', '1::24'],
#  ['3::17', '4::19', '5::19', '6::19'],
#  ['0::6', '1::13'],
#  ['0::16', '1::16', '2::18', '3::30'],
#  ['0::8'],
#  ['0::19', '1::42', '2::51'],
#  ['0::18', '1::19'],
#  ['0::45', '1::8', '2::6'],
#  ['0::88', '1::41'],
#  ['1::30'],
#  ['0::62', '1::38', '2::37'],
#  ['0::34', '1::15'],
#  nan,
#  ['1::22'],
#  ['0::18', '1::20', '2::25'],
#  nan,
#  ['0::34', '1::32'],
#  nan,
#  nan,
#  ['0::52', '1::38'],
#  nan,
#  nan,
#  nan,
#  ['0::22'],
#  ['0::47', '1::23'],
#  nan,
#  nan,
#  nan,
#  ['0::25', '1::22'],
#  nan,
#  nan,
#  ['0::27', '1::35'],
#  ['1::21'],
#  ['0::22', '1::22'],
#  nan,
#  ['0::25'],
#  nan,
#  ['0::22', '1::32'],
#  ['0::39'],
#  nan,
#  ['0::28'],
#  nan,
#  ['0::33'],
#  ['0::43', '1::48'],
#  ['0::21', '1::25'],
#  ['0::47'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['2::19'],
#  ['1::23'],
#  ['0::21'],
#  ['0::28'],
#  ['0::61'],
#  nan,
#  nan,
#  ['0::35', '1::42'],
#  ['0::33', '1::35'],
#  nan,
#  nan,
#  nan,
#  ['0::49'],
#  ['0::20'],
#  nan,
#  ['3::25'],
#  ['1::24'],
#  ['0::17'],
#  ['2::24'],
#  ['0::73'],
#  ['0::36', '1::28', '2::23', '3::23'],
#  ['0::34'],
#  nan,
#  nan,
#  ['0::21', '1::19', '2::17'],
#  nan,
#  ['0::48'],
#  ['0::24'],
#  ['0::25'],
#  nan,
#  nan,
#  ['3::24'],
#  nan,
#  ['0::15', '1::22'],
#  nan,
#  ['0::27', '1::30'],
#  ['0::36'],
#  nan,
#  ['0::48', '1::21'],
#  nan,
#  ['0::30'],
#  ['0::18'],
#  ['0::24', '1::21'],
#  ['0::37', '1::42', '2::37', '3::42'],
#  nan,
#  ['0::21'],
#  ['0::32'],
#  ['0::36'],
#  ['0::18', '1::18'],
#  ['0::19', '1::30'],
#  ['0::48'],
#  ['0::28'],
#  ['0::26'],
#  nan,
#  ['0::50'],
#  nan,
#  ['0::27', '1::29', '2::25'],
#  ['0::9'],
#  nan,
#  ['0::42', '1::27'],
#  ['0::41', '1::63'],
#  nan,
#  ['0::20'],
#  ['0::27'],
#  ['0::23'],
#  ['1::26'],
#  ['0::20'],
#  nan,
#  ['0::33'],
#  nan,
#  ['0::6', '1::21'],
#  nan,
#  ['0::33'],
#  nan,
#  ['0::24'],
#  ['0::36'],
#  ['0::34', '1::17'],
#  nan,
#  ['0::33'],
#  nan,
#  ['0::3', '1::24'],
#  ['0::28', '1::28'],
#  nan,
#  ['1::26'],
#  ['4::37'],
#  ['1::23'],
#  ['0::36', '1::41'],
#  nan,
#  ['0::32'],
#  ['0::18', '1::19', '2::19'],
#  nan,
#  ['1::2'],
#  ['0::28'],
#  ['0::53'],
#  ['0::22', '1::58'],
#  nan,
#  nan,
#  ['0::29', '1::48'],
#  nan,
#  nan,
#  ['1::35'],
#  ['0::17'],
#  ['1::18', '2::17'],
#  ['0::71', '1::70'],
#  nan,
#  ['0::37', '1::27'],
#  ['0::25'],
#  ['0::16'],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::17'],
#  nan,
#  ['0::25'],
#  nan,
#  ['0::39'],
#  ['0::28', '1::30'],
#  nan,
#  nan,
#  ['0::23', '1::30'],
#  ['0::23', '1::27', '2::17'],
#  ['0::35', '1::15'],
#  ['0::31'],
#  ['0::46'],
#  ['1::36'],
#  ['0::30'],
#  nan,
#  nan,
#  nan,
#  ['0::27'],
#  nan,
#  nan,
#  nan,
#  ['0::27', '1::29'],
#  nan,
#  ['0::22'],
#  ['1::20', '2::23'],
#  nan,
#  ['0::49'],
#  ['0::16', '1::15', '2::17', '3::34'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::23', '1::17', '2::20', '3::20'],
#  nan,
#  nan,
#  nan,
#  ['0::14'],
#  ['2::38', '3::33'],
#  nan,
#  ['0::12', '1::22'],
#  nan,
#  ['1::23'],
#  nan,
#  ['0::36'],
#  ['0::37', '1::21'],
#  nan,
#  ['0::19', '1::21'],
#  nan,
#  ['0::16'],
#  ['0::19', '1::21'],
#  nan,
#  ['0::50'],
#  nan,
#  ['0::24'],
#  ['0::20'],
#  ['1::20'],
#  nan,
#  ['0::19', '1::30'],
#  nan,
#  ['0::37'],
#  nan,
#  nan,
#  ['0::32'],
#  nan,
#  ['0::43'],
#  nan,
#  nan,
#  ['0::37'],
#  nan,
#  ['0::22', '1::58'],
#  nan,
#  nan,
#  nan,
#  ['0::59', '1::49'],
#  ['0::58'],
#  ['0::60'],
#  ['0::20'],
#  ['0::18'],
#  ['0::42'],
#  ['0::18', '1::18', '2::18', '3::19'],
#  ['0::16', '2::17', '3::16'],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::66'],
#  nan,
#  nan,
#  nan,
#  ['0::24', '1::41'],
#  ['1::20', '2::27'],
#  nan,
#  nan,
#  ['0::24'],
#  nan,
#  nan,
#  ['1::45'],
#  nan,
#  ['1::24'],
#  ['0::30'],
#  nan,
#  nan,
#  ['0::29'],
#  nan,
#  ['0::30'],
#  nan,
#  nan,
#  ['0::25'],
#  nan,
#  ['0::37'],
#  nan,
#  ['0::5'],
#  ['0::22', '1::17'],
#  nan,
#  ['0::47'],
#  ['0::43', '1::22'],
#  nan,
#  nan,
#  ['0::35', '1::33'],
#  nan,
#  ['1::18'],
#  ['0::23'],
#  ['0::37', '1::1', '2::4', '3::5', '4::19', '5::16'],
#  ['0::39'],
#  ['0::34', '1::45'],
#  ['0::18', '1::18'],
#  ['1::34'],
#  ['2::20'],
#  ['0::24'],
#  ['0::21', '1::24'],
#  nan,
#  nan,
#  nan,
#  ['0::42', '1::22', '2::22', '3::20', '4::42'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::28', '1::38'],
#  nan,
#  nan,
#  ['0::33'],
#  ['0::32', '1::23'],
#  ['0::18', '1::17'],
#  ['3::17'],
#  nan,
#  nan,
#  ['0::30', '1::30'],
#  ['0::19'],
#  ['1::21'],
#  ['0::26'],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ['2::47'],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::44'],
#  ['0::19', '1::31', '2::20', '3::18', '4::23', '5::22'],
#  nan,
#  nan,
#  ['1::23'],
#  ['0::32', '1::27'],
#  ['0::71', '1::89', '2::31', '3::33', '4::34'],
#  nan,
#  nan,
#  nan,
#  ['0::23', '1::23'],
#  nan,
#  ['0::37'],
#  ['0::20'],
#  nan,
#  nan,
#  ['0::90'],
#  ['0::43', '1::37'],
#  nan,
#  nan,
#  ['0::35', '1::33'],
#  ['0::23'],
#  nan,
#  ['0::46', '1::47'],
#  nan,
#  ['0::19', '1::18'],
#  ['0::38', '1::35'],
#  ['0::30', '1::30'],
#  nan,
#  ['0::23', '1::25'],
#  ['0::25'],
#  ['0::26', '1::23'],
#  nan,
#  ['0::16'],
#  ['0::23', '1::20', '2::17'],
#  ['0::17'],
#  nan,
#  ['0::52', '1::27'],
#  nan,
#  ['0::32', '1::19'],
#  ['0::41'],
#  ['0::23'],
#  nan,
#  ['1::27'],
#  ['1::52'],
#  nan,
#  nan,
#  ['0::19'],
#  ['0::53'],
#  ['0::30'],
#  ['0::47'],
#  nan,
#  ['0::22', '1::21', '2::21', '3::18'],
#  nan,
#  nan,
#  ['0::55', '1::23'],
#  nan,
#  nan,
#  ['0::21'],
#  nan,
#  ['1::21'],
#  ['0::30'],
#  nan,
#  nan,
#  ['0::33', '1::45'],
#  ['0::35', '1::34'],
#  ['0::25', '1::32'],
#  ['0::33', '1::49'],
#  nan,
#  nan,
#  ['0::31', '1::36'],
#  ['1::27'],
#  nan,
#  ['0::45', '1::51'],
#  ['1::19'],
#  nan,
#  ['2::36'],
#  ['0::48', '1::26'],
#  ['1::55'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::21', '1::19'],
#  nan,
#  nan,
#  ['0::27', '1::27'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['2::19', '3::26'],
#  nan,
#  nan,
#  ['0::33'],
#  ['0::72'],
#  ['1::34'],
#  ['0::43'],
#  nan,
#  ['0::32'],
#  ['0::34', '1::37', '2::22', '3::40'],
#  ['0::19', '1::20', '2::19', '3::20'],
#  nan,
#  ['0::23', '1::18'],
#  ['0::22'],
#  ['0::34'],
#  ['0::20', '1::21', '2::23', '3::20'],
#  ['0::19'],
#  ['0::22'],
#  ['0::41'],
#  nan,
#  nan,
#  nan,
#  ['0::66'],
#  ['1::70'],
#  ['1::46'],
#  ['0::23'],
#  ['2::16'],
#  ['0::16'],
#  nan,
#  nan,
#  nan,
#  ['0::40'],
#  ['1::88'],
#  nan,
#  ['0::58', '1::48'],
#  nan,
#  ['0::22', '1::25'],
#  ['1::23'],
#  ['0::34'],
#  nan,
#  ['0::31', '1::29'],
#  nan,
#  ['0::68', '1::38'],
#  nan,
#  ['0::22', '1::50', '2::31', '3::54', '4::36'],
#  ['0::57', '1::20', '2::20'],
#  ['0::29'],
#  nan,
#  ['0::23'],
#  nan,
#  ['0::13', '1::15', '2::18'],
#  ['0::21'],
#  nan,
#  ['0::23'],
#  ['1::29'],
#  ['0::28'],
#  ['0::24'],
#  ['0::23', '1::23'],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::22'],
#  ['0::53', '1::39'],
#  ['0::20', '1::20'],
#  nan,
#  ['0::42'],
#  ['0::34'],
#  nan,
#  nan,
#  nan,
#  ['0::23', '1::28'],
#  ['0::49'],
#  ['0::21', '1::21', '3::24'],
#  nan,
#  ['0::32', '1::27'],
#  ['0::25'],
#  nan,
#  ['0::59'],
#  ['0::64', '1::39'],
#  ['1::20'],
#  ['0::28', '1::36'],
#  ['0::53', '1::61', '2::23'],
#  ['0::55', '1::32'],
#  ['0::37'],
#  nan,
#  ['1::18'],
#  nan,
#  ['0::43', '1::66'],
#  ['0::70', '1::67', '2::70'],
#  nan,
#  ['0::26'],
#  nan,
#  nan,
#  ['0::28'],
#  ['0::49'],
#  ['1::51'],
#  nan,
#  ['0::21', '1::24'],
#  ['0::57'],
#  nan,
#  nan,
#  nan,
#  ['0::20'],
#  ['0::15', '1::28'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::20', '1::21', '2::21', '3::21', '4::21'],
#  ['0::36'],
#  nan,
#  ['0::24'],
#  nan,
#  nan,
#  ['0::28'],
#  ['0::25'],
#  nan,
#  ['0::26', '1::36'],
#  nan,
#  ['0::24', '3::20', '4::18'],
#  nan,
#  nan,
#  ['0::25', '1::55'],
#  nan,
#  nan,
#  nan,
#  ['0::37'],
#  ['0::67', '1::70'],
#  ['0::26'],
#  ['0::18'],
#  nan,
#  ['0::23', '1::21', '2::19', '3::21', '4::20'],
#  ['0::31', '1::9', '2::23'],
#  ['0::69', '1::63'],
#  ['0::17', '1::17'],
#  ['0::33'],
#  nan,
#  ['0::29'],
#  nan,
#  ['0::33', '1::36'],
#  nan,
#  nan,
#  ['0::10', '1::30'],
#  nan,
#  ['0::56'],
#  ['1::36'],
#  nan,
#  ['0::28'],
#  ['2::30'],
#  nan,
#  ['0::23'],
#  ['0::24'],
#  ['0::31'],
#  nan,
#  nan,
#  ['0::22', '1::21', '2::19', '3::25'],
#  nan,
#  ['0::20'],
#  ['0::23', '1::28'],
#  ['0::22'],
#  ['0::19', '1::20'],
#  ['1::49'],
#  ['0::16', '1::13'],
#  nan,
#  ['0::32'],
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::51'],
#  ['0::25', '1::18', '2::21'],
#  ['0::22'],
#  nan,
#  ['0::27'],
#  ['0::37', '1::19'],
#  ['1::21'],
#  nan,
#  ['4::27', '5::29', '6::27'],
#  nan,
#  ['1::40'],
#  nan,
#  ['0::63', '1::16'],
#  nan,
#  ['0::18'],
#  ['0::22'],
#  ['1::22'],
#  nan,
#  ['0::19', '1::48'],
#  nan,
#  ['0::26', '1::20', '2::18', '3::19'],
#  nan,
#  ['0::18'],
#  ['0::24', '1::23'],
#  ['0::18'],
#  ['0::21'],
#  nan,
#  nan,
#  ['0::36'],
#  ['0::27'],
#  nan,
#  nan,
#  ['0::19'],
#  ['0::17', '1::20'],
#  nan,
#  ['0::22'],
#  nan,
#  ['0::23', '1::20'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::27'],
#  nan,
#  ['0::20'],
#  ['1::55'],
#  ['0::26', '1::34'],
#  nan,
#  ['0::24', '1::24', '2::22'],
#  nan,
#  nan,
#  ['0::24'],
#  nan,
#  ['0::27', '1::30'],
#  ['0::7', '1::18'],
#  ['0::64'],
#  ['0::46'],
#  nan,
#  nan,
#  nan,
#  ['0::26', '4::21'],
#  nan,
#  nan,
#  nan,
#  ['0::46', '1::55'],
#  ['0::21', '1::26'],
#  nan,
#  ['0::25', '1::29'],
#  ['0::17', '2::17'],
#  ['1::40'],
#  nan,
#  nan,
#  nan,
#  nan,
#  ['0::18'],
#  ['0::21'],
#  ['0::24'],
#  ['0::30'],
#  ['0::33'],
#  ['0::22'],
#  nan,
#  ['0::26'],
#  nan,
#  nan,
#  nan,
#  ['2::23'],
#  nan,
#  nan,
#  ['0::18'],
#  nan,
#  ['0::24', '1::36'],
#  ...]

# %%
ages = [np.mean([float(y.split(':')[-1]) for y in x]) if x is not np.nan else np.nan for x  in ages]

# %%
data['mean_age'] = ages

# %% [markdown]
# *Странноватый формат записи возраста, если честно*

# %% [markdown]
# # Отрисовка всевозможных карт

# %% [markdown]
# ### Число происшествий

# %%
fig = show_USA(incidents_by_state, 'Число преступлений с применением оружия', 'Число происшествий')
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~aleksey_dumbay/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aleksey_dumbay/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Число происшествий на душу населения

# %%
fig = show_USA(incidents_by_state / population_data, 'Число преступлений с применением оружия на душу населения', 'Число происшествий')
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~aleksey_dumbay/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aleksey_dumbay/0.embed" height="525px" width="100%"></iframe>

# %%
incidents_by_state / population_data
# Out:
# Alabama                 0.001119
# Alaska                  0.001828
# Arizona                 0.000327
# Arkansas                0.000941
# California              0.000410
# Colorado                0.000563
# Connecticut             0.000855
# Delaware                0.001735
# District of Columbia    0.004541
# Florida                 0.000705
# Georgia                 0.000846
# Hawaii                  0.000203
# Idaho                   0.000377
# Illinois                0.001375
# Indiana                 0.000873
# Iowa                    0.000796
# Kansas                  0.000735
# Kentucky                0.000930
# Louisiana               0.001730
# Maine                   0.000676
# Maryland                0.000954
# Massachusetts           0.000867
# Michigan                0.000614
# Minnesota               0.000428
# Mississippi             0.001207
# Missouri                0.001081
# Montana                 0.000601
# Nebraska                0.000854
# Nevada                  0.000639
# New Hampshire           0.000714
# New Jersey              0.000596
# New Mexico              0.000787
# New York                0.000489
# North Carolina          0.000841
# North Dakota            0.000759
# Ohio                    0.000876
# Oklahoma                0.000877
# Oregon                  0.000544
# Pennsylvania            0.000696
# Rhode Island            0.000843
# South Carolina          0.001364
# South Dakota            0.000620
# Tennessee               0.001124
# Texas                   0.000473
# Utah                    0.000339
# Vermont                 0.000756
# Virginia                0.000698
# Washington              0.000456
# West Virginia           0.000874
# Wisconsin               0.000823
# Wyoming                 0.000861
# dtype: float64

# %% [markdown]
# _Колумбия_

# %% [markdown]
# ### Число убитых к инцидентам

# %%
diff = data.groupby('state').n_killed.sum() / data.groupby('state').n_killed.count()

# %%
fig = show_USA(diff, 'Отношение числа убийст к числу инцидентов', 'Отношение')
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~aleksey_dumbay/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aleksey_dumbay/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Число убитых к населению

# %%
diff_1 = data.groupby('state').n_killed.sum() / population_data

# %%
fig = show_USA(diff_1, 'Отношение числа убийст к населению', 'Отношение')
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~aleksey_dumbay/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aleksey_dumbay/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Средний возраст по штатам

# %%
diff_age = data.groupby('state').mean_age.mean() 
fig = show_USA(diff_age, 'Средний возраст участников', 'Возраст, лет')
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~aleksey_dumbay/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aleksey_dumbay/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Число раненых к числу инцидентов

# %%
diff_inj = data.groupby('state').n_injured.sum() / data.groupby('state').n_injured.count()
fig = show_USA(diff_inj, 'Отношение числа раненых к числу инцидентов', 'Отношение')
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~aleksey_dumbay/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aleksey_dumbay/0.embed" height="525px" width="100%"></iframe>

# %%
sub_data = np.random.choice(len(data), size=(5000), replace=False)

# %%
trace = go.Scatter(x=data.iloc[sub_data].n_killed + np.random.rand(len(sub_data))*0.2, 
                   y=data.iloc[sub_data].n_injured + np.random.rand(len(sub_data))*0.4, 
                   mode = 'markers')
layout = dict(title = 'Убийства и раненые',
               xaxis= dict(
                    title= 'Убитые',
                    ticklen= 5,
                    zeroline= False,
                    gridwidth= 1,
                    dtick=1,
                ),
                yaxis=dict(
                    title= 'Раненые',
                    ticklen= 5,
                    gridwidth= 1,
                    dtick=1,
                ),
             )

plot_data = [trace]
py.iplot({'data': plot_data, 'layout':layout}, filename='basic-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aleksey_dumbay/2.embed" height="525px" width="100%"></iframe>

# %%
sub_data = np.random.choice(len(data), size=(5000), replace=False)

# %% [markdown]
# ### Города

# %%
top_places = data.groupby('city_or_county').date.count()

# %%
tp = top_places.sort_values()[-20:]

# %%
data1 = [go.Bar(
            x=tp,
            y=tp.index,
            orientation = 'h'
)]
layout = {'title':'Число инцидентов'}
py.iplot({'data': data1, 'layout':layout}, filename='horizontal-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~aleksey_dumbay/5.embed" height="525px" width="100%"></iframe>

# %%
sub_data = np.random.choice(len(data), size=(10000), replace=False)

# %%
trace = go.Scatter(x=data.iloc[sub_data].n_killed + np.random.rand(len(sub_data))*0.2, 
                   y=data.iloc[sub_data].n_guns_involved + np.random.rand(len(sub_data))*0.4, 
                   mode = 'markers')
layout = dict(title = 'Убийства и используемые орудия',
               xaxis= dict(
                    title= 'Убитые',
                    ticklen= 5,
                    zeroline= False,
                    gridwidth= 1,
                    dtick=1,
                ),
                yaxis=dict(
                    title= 'Оружие',
                    ticklen= 5,
                    gridwidth= 1,
                ),
             )

plot_data = [trace]
py.iplot({'data': plot_data, 'layout':layout}, filename='basic-scatter')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-34-61b630cae7cd> in <module>()
#      18
#      19 plot_data = [trace]
# ---> 20 py.iplot({'data': plot_data, 'layout':layout}, filename='basic-scatter')
#
# C:\Python\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     143     if 'auto_open' not in plot_options:
#     144         plot_options['auto_open'] = False
# --> 145     url = plot(figure_or_data, **plot_options)
#     146
#     147     if isinstance(figure_or_data, dict):
#
# C:\Python\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in plot(figure_or_data, validate, **plot_options)
#     240     data = fig.get('data', [])
#     241     plot_options['layout'] = fig.get('layout', {})
# --> 242     response = v1.clientresp(data, **plot_options)
#     243
#     244     # Check if the url needs a secret key
#
# C:\Python\Anaconda3\lib\site-packages\plotly\api\v1\clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# C:\Python\Anaconda3\lib\site-packages\retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# C:\Python\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     204
#     205             if not self.should_reject(attempt):
# --> 206                 return attempt.get(self._wrap_exception)
#     207
#     208             delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#
# C:\Python\Anaconda3\lib\site-packages\retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# C:\Python\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# C:\Python\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# C:\Python\Anaconda3\lib\site-packages\plotly\api\v1\utils.py in request(method, url, **kwargs)
#      88         content = response.content if response else 'No content'
#      89         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 90     validate_response(response)
#      91     return response
#
# C:\Python\Anaconda3\lib\site-packages\plotly\api\v1\utils.py in validate_response(response)
#      38         message = content if content else 'No Content'
#      39
# ---> 40     raise exceptions.PlotlyRequestError(message, status_code, content)
#      41
#      42
#
# PlotlyRequestError: Hi there, you've reached the threshold of 100 combined image exports and chart saves per 24h period. If you need to raise your daily limit, please consider upgrading to a paid plan
# (see: https://plot.ly/products/cloud ).

# %% [markdown]
# ### Среднее число убитых с использованием числа оружия

# %%
data.groupby('n_guns_involved').date.count()

# %%
by_gun = data.groupby('n_guns_involved').n_killed.mean()
inj_gun = data.groupby('n_guns_involved').n_injured.mean()
idx = (by_gun > 0) | (inj_gun > 0)
by_gun = by_gun[idx]
inj_gun = inj_gun[idx]
layout = go.Layout(
    title='Результаты, в зависимости от фигурировавшего вооружения',
    xaxis=dict(
        title='Число вооружения в инциденте',
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        ),
    ),
    yaxis=dict(
        title='В среднем жертв',
        titlefont=dict(
            size=16,
            color='rgb(107, 107, 107)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)
gun_data = go.Bar(
            x=by_gun.index,
            y=by_gun,
            name='Среднее число убитых')
inj_data = go.Bar(
            x=inj_gun.index,
            y=inj_gun,
            name='Среднее число раненых')
gun_data = [gun_data, inj_data]
py.iplot({'data': gun_data, 'layout':layout}, filename='basic-scatter')

# %%
data[data.n_guns_involved==81]

# %%
data[data.n_guns_involved==33]

# %% [markdown]
# ### Общее число

# %%
by_gun = data.groupby('n_guns_involved').n_killed.sum()
inj_gun = data.groupby('n_guns_involved').n_injured.sum()
idx = (by_gun > 0) | (inj_gun > 0)
by_gun = by_gun[idx]
inj_gun = inj_gun[idx]
layout = go.Layout(
    title='Число используемого оружия',
    xaxis=dict(
        title='Число оружия',
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        ),
    ),
    yaxis=dict(
        title='Среднее число убитых',
        titlefont=dict(
            size=16,
            color='rgb(107, 107, 107)'
        ),
        tickfont=dict(
            size=14,
            color='rgb(107, 107, 107)'
        )
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15,
    bargroupgap=0.1
)
gun_data = go.Bar(
            x=by_gun.index,
            y=by_gun,
            name='Среднее число убитых')
inj_data = go.Bar(
            x=inj_gun.index,
            y=inj_gun,
            name='Среднее число раненых')
gun_data = [gun_data, inj_data]
py.iplot({'data': gun_data, 'layout':layout}, filename='basic-scatter')
